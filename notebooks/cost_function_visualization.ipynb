# %% [markdown]
# # Binary logistic regression

# %% [markdown]
# * Given a model output $z$, the logistic function outputs a probability estimate $\hat{p}$ between 0 and 1:
#
# $$\hat{p} = \sigma(z) = \frac{1}{1+e^{-z}}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# plot logistic sigmoid function
zvals = np.arange(-10, 10, 0.01)
logistic = lambda x: 1/(1+np.exp(-x))
pvals = logistic(zvals)
fig, ax = plt.subplots(figsize=(8, 4))
plt.title("Standard logistic sigmoid function")
plt.plot(zvals, pvals, label="Logistic sigmoid")
plt.xlabel("Model output (z)")
plt.ylabel("Estimated probability (p)")
plt.axhline(y=0.5, color='k', linestyle='dashed', 
            label="Decision boundary for binary classification")
plt.legend()
pass

# %% [markdown]
# **Logistic regression cost function**
#
# $$J(\theta) = - \frac{1}{m} \sum_{i=1}^m [y_i \log(\hat{p_i}) + (1-y_i)\log(1-\hat{p_i})]$$

# %%
# plotting logistic regression cost function for given y value (parameter "y_true" below)
def logloss(y, y_hat, alpha=1):
  logloss = -(alpha * y * np.log(y_hat) + (1-y) * np.log(1-y_hat))
  return logloss

# %%
# generate random y_true distribution from set {0,1}
y_true = np.random.randint(0.0, 2.0, 1000) 
# generate random predictions between 0 and 1 (float)
y_pred = np.arange(0,1, 0.001)
y_logloss = logloss(y_true, y_pred, alpha=1)

fig, ax = plt.subplots(figsize=(8, 4))
plt.plot(y_pred, y_logloss)
plt.title("Logistic loss")
plt.xlabel("Predicted values (y_predicted)")
plt.ylabel("Log loss")
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
# logloss with alpha = 2
y_logloss = logloss(y_true, y_pred, alpha=2)

fig, ax = plt.subplots(figsize=(8, 4))
plt.plot(y_pred, y_logloss)
plt.title("Logistic loss")
plt.xlabel("Predicted values (y_predicted)")
plt.ylabel("Log loss")
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
true_labels = np.random.randint(0.0, 2.0, 2)
neg_labels = np.random.randint(0.0, 1.0, 998)
y_true = np.concatenate((true_labels, neg_labels), axis=None)

# %%
# generate random y_true distribution from set {0,1}
y_true = 1 
# generate random predictions between 0 and 1 (float)
y_pred = np.arange(0,1, 0.0000001)
y_logloss = logloss(y_true, y_pred, alpha=1)

fig, ax = plt.subplots(figsize=(8, 4))
plt.plot(y_pred, y_logloss)
plt.title("Logistic loss")
plt.xlabel("Predicted values (y_predicted)")
plt.ylabel("Log loss")
plt.ylim([-0.5,7.0])
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
y_true = 1 
y_logloss1 = logloss(y_true, y_pred, alpha=2)
y_logloss2 = logloss(y_true, y_pred, alpha=5)
y_logloss3 = logloss(y_true, y_pred, alpha=10)
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(y_pred, y_logloss, 'k-', label=r'$\alpha=1$')
plt.plot(y_pred, y_logloss1, 'k--', label=r'$\alpha=2$')
plt.plot(y_pred, y_logloss2, 'k-.', label=r'$\alpha=5$')
plt.plot(y_pred, y_logloss3, 'k:', label=r'$\alpha=10$')
# plt.title("Binary cross-entropy loss for y_true='{}'".format(y_true))
plt.xlabel("Predicted values")
plt.ylabel("Loss")
plt.ylim([-0.5,20.0])
plt.legend()
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax = plt.subplots(figsize=(15,8))
plt.plot(y_pred, y_logloss, label='log loss for alpha=1')
plt.plot(y_pred, y_logloss1, label='log loss for alpha=2')
plt.plot(y_pred, y_logloss2, label='log loss for alpha=5')
plt.plot(y_pred, y_logloss3, label='log loss for alpha=10')
plt.title("Binary cross-entropy loss for y_true='{}'".format(y_true))
plt.xlabel("Predicted values")
plt.ylabel("Loss")
plt.ylim([-0.5,20.0])
plt.legend()
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# generate random y_true distribution from set {0,1}
y_true = 0 
# generate random predictions between 0 and 1 (float)
y_pred = np.arange(0,1, 0.001)
y_logloss = logloss(y_true, y_pred, alpha=1)

fig, ax = plt.subplots(figsize=(8, 4))
plt.plot(y_pred, y_logloss)
plt.title("Logistic loss")
plt.xlabel("Predicted values (y_predicted)")
plt.ylabel("Log loss")
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
# generate random y_true distribution from set {0,1}
y_true = 0 
# generate random predictions between 0 and 1 (float)
y_pred = np.arange(0,1, 0.001)
y_logloss = logloss(y_true, y_pred, alpha=10)

fig, ax = plt.subplots(figsize=(8, 4))
plt.plot(y_pred, y_logloss)
plt.title("Logistic loss")
plt.xlabel("Predicted values (y_predicted)")
plt.ylabel("Log loss")
pass
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply
